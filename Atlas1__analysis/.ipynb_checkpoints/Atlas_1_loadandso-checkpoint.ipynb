# %%
import pandas as pd
from scipy import stats
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
def make_var_df(input_csv):
    tpm_df = pd.read_csv(input_csv, index_col=0)
    coef_var = np.log10((tpm_df.std(axis=1)/tpm_df.mean(axis=1))**2)
    means = np.log10(tpm_df.mean(axis=1))
    result = stats.linregress(means, coef_var)
    slope = result[0]
    y_int = result[1]
    var_df = pd.DataFrame([coef_var, means]).T
    var_df.rename(columns = {0:'coef_var',1:'mean'}, inplace=True)
    var_df['expected'] = var_df['mean']*slope + y_int
    
    return var_df

# %%
tpm_input_file = "/oasis/tscc/scratch/cshl_2018/atlas1_full_counts/tpm_all.csv"
#specify input file
save_dir = "/home/ucsd-train13/scratch/projects/Atlas_full/processed_files/"
#specify save directory

# %%
tpm = pd.read_csv(tpm_input_file, index_col=0)
#load matrix
print(tpm.shape)
tpm.head()
# Out:
# (15971, 7216)
#          B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  B1_AAACCGTGCCAAGT_Tuft  \
# Mrpl15                                       3.273858                3.373819
# Lypla1                                       3.273858                0.000000
# Gm37988                                      0.000000                0.000000
# Tcea1                                        0.000000                0.000000
# Atp6v1h                                      0.000000                0.000000
#
#          B1_AAACGCACAGCCTA_Goblet  B1_AAACGCACCAGATC_Endocrine  \
# Mrpl15                   2.495633                     2.273761
# Lypla1                   0.000000                     1.136880
# Gm37988                  0.000000                     0.000000
# Tcea1                    0.000000                     0.000000
# Atp6v1h                  0.000000                     0.000000
#
#          B1_AAACGCACCGCCTT_Stem  B1_AAACGCACCGTAGT_Stem  \
# Mrpl15                      0.0                4.713091
# Lypla1                      0.0                0.000000
# Gm37988                     0.0                0.000000
# Tcea1                       0.0                0.000000
# Atp6v1h                     0.0                0.000000
#
#          B1_AAACGGCTGATAGA_TA.Early  \
# Mrpl15                          0.0
# Lypla1                          0.0
# Gm37988                         0.0
# Tcea1                           0.0
# Atp6v1h                         0.0
#
#          B1_AAACTTGAAGAGTA_Enterocyte.Mature.Proximal  \
# Mrpl15                                       1.920492
# Lypla1                                       0.000000
# Gm37988                                      0.000000
# Tcea1                                        0.000000
# Atp6v1h                                      0.000000
#
#          B1_AAACTTGACCACAA_TA.G1  \
# Mrpl15                  2.990431
# Lypla1                  0.747608
# Gm37988                 0.000000
# Tcea1                   0.000000
# Atp6v1h                 0.000000
#
#          B1_AAAGACGATTGTCT_Enterocyte.Mature.Proximal  \
# Mrpl15                                            0.0
# Lypla1                                            0.0
# Gm37988                                           0.0
# Tcea1                                             0.0
# Atp6v1h                                           0.0
#
#                    ...              \
# Mrpl15             ...
# Lypla1             ...
# Gm37988            ...
# Tcea1              ...
# Atp6v1h            ...
#
#          B10_TTCAGTTGCCTCGT_Enterocyte.Mature.Proximal  \
# Mrpl15                                        3.446691
# Lypla1                                        0.000000
# Gm37988                                       0.000000
# Tcea1                                         0.000000
# Atp6v1h                                       0.000000
#
#          B10_TTCATGACCATTCT_Enterocyte.Progenitor.Early  \
# Mrpl15                                         1.757469
# Lypla1                                         0.000000
# Gm37988                                        0.000000
# Tcea1                                          0.000000
# Atp6v1h                                        0.878735
#
#          B10_TTCATGTGCGAGTT_Goblet  B10_TTCCAAACTAGAGA_Goblet  \
# Mrpl15                         0.0                   0.000000
# Lypla1                         0.0                   0.000000
# Gm37988                        0.0                   0.000000
# Tcea1                          0.0                   0.000000
# Atp6v1h                        0.0                   2.082899
#
#          B10_TTCGGAGAGACGTT_Enterocyte.Progenitor.Early  \
# Mrpl15                                              0.0
# Lypla1                                              0.0
# Gm37988                                             0.0
# Tcea1                                               0.0
# Atp6v1h                                             0.0
#
#          B10_TTCTACGAATGCCA_Enterocyte.Progenitor.Early  \
# Mrpl15                                         8.877710
# Lypla1                                         0.739809
# Gm37988                                        0.000000
# Tcea1                                          0.000000
# Atp6v1h                                        1.479618
#
#          B10_TTCTGATGGCATCA_Enterocyte.Progenitor.Early  \
# Mrpl15                                              0.0
# Lypla1                                              0.0
# Gm37988                                             0.0
# Tcea1                                               0.0
# Atp6v1h                                             0.0
#
#          B10_TTGACACTACCAAC_TA.G2  \
# Mrpl15                        0.0
# Lypla1                        0.0
# Gm37988                       0.0
# Tcea1                         0.0
# Atp6v1h                       0.0
#
#          B10_TTGAGGTGTACTCT_Enterocyte.Mature.Proximal  \
# Mrpl15                                       10.992031
# Lypla1                                        0.000000
# Gm37988                                       0.000000
# Tcea1                                         0.000000
# Atp6v1h                                       0.000000
#
#          B10_TTGCTATGGGCATT_Paneth
# Mrpl15                    1.923151
# Lypla1                    0.384630
# Gm37988                   0.000000
# Tcea1                     0.000000
# Atp6v1h                   0.384630
#
# [5 rows x 7216 columns]

# %%
#show expample of 1 cell
plt.hist(tpm['B1_AAACCGTGCCAAGT_Tuft'])
plt.ylabel("FPKM")
plt.show()

# %%
###Define highly variable genes for downstream analyses
#first calculate stdevs of all genes across cells
sd = tpm.std(axis=1)
sd.head()
# Out:
# Mrpl15     3.334953
# Lypla1     2.101972
# Gm37988    0.040944
# Tcea1      0.682425
# Atp6v1h    1.120129
# dtype: float64

# %%
#calculate mean across genes
mean_expr = tpm.mean(axis=1)
mean_expr.head()
# Out:
# Mrpl15     2.626871
# Lypla1     1.065084
# Gm37988    0.000782
# Tcea1      0.201816
# Atp6v1h    0.320952
# dtype: float64

# %%
#to calculate coefficient variation
coef_var = np.log10((sd/mean_expr)**2)
#####note: findsimilargenes in SEURAT does something similar
coef_var.head()
# Out:
# Mrpl15     0.207302
# Lypla1     0.590486
# Gm37988    3.437682
# Tcea1      1.058197
# Atp6v1h    1.085655
# dtype: float64

# %%
#calculate means of expression for all genes
means = np.log10(mean_expr)
means.head()
# Out:
# Mrpl15     0.419439
# Lypla1     0.027384
# Gm37988   -3.106656
# Tcea1     -0.695044
# Atp6v1h   -0.493559
# dtype: float64

# %%
reg_result = stats.linregress(means, coef_var)
reg_result
# Out:
# LinregressResult(slope=-0.9006364144049142, intercept=0.7199867215099409, rvalue=-0.9824119932949177, pvalue=0.0, stderr=0.0013546348854553574)

# %%
slope = reg_result[0]
yint = reg_result[1]

# %%
var_df = pd.DataFrame([coef_var, means]).T
var_df.rename(columns = {0:"coef_var", 1:"mean"}, inplace=True)
var_df.head()
# Out:
#          coef_var      mean
# Mrpl15   0.207302  0.419439
# Lypla1   0.590486  0.027384
# Gm37988  3.437682 -3.106656
# Tcea1    1.058197 -0.695044
# Atp6v1h  1.085655 -0.493559

# %%
sns.lmplot('mean', 'coef_var', var_df, fit_reg=False)

# %%
var_df['expected'] = var_df['mean']*slope + yint
var_df.head()
# Out:
#          coef_var      mean  expected
# Mrpl15   0.207302  0.419439  0.342225
# Lypla1   0.590486  0.027384  0.695324
# Gm37988  3.437682 -3.106656  3.517954
# Tcea1    1.058197 -0.695044  1.345968
# Atp6v1h  1.085655 -0.493559  1.164504

# %%
tpm_input_file
# Out:
# '/oasis/tscc/scratch/cshl_2018/atlas1_full_counts/tpm_all.csv'

# %%
var_df = make_var_df(tpm_input_file)
var_df.head()
# Out:
#          coef_var      mean  expected
# Mrpl15   0.207302  0.419439  0.342225
# Lypla1   0.590486  0.027384  0.695324
# Gm37988  3.437682 -3.106656  3.517954
# Tcea1    1.058197 -0.695044  1.345968
# Atp6v1h  1.085655 -0.493559  1.164504

# %%
#define significant genes and add this as column
var_df['sig'] = (var_df['coef_var'] - var_df['expected']) > 0.05
var_df.head()
# Out:
#          coef_var      mean  expected    sig
# Mrpl15   0.207302  0.419439  0.342225  False
# Lypla1   0.590486  0.027384  0.695324  False
# Gm37988  3.437682 -3.106656  3.517954  False
# Tcea1    1.058197 -0.695044  1.345968  False
# Atp6v1h  1.085655 -0.493559  1.164504  False

# %%
var_df['sig'].sum()
# Out:
# 4067

# %%
sns.lmplot('mean', 'coef_var', var_df, hue='sig', fit_reg=False)

# %%
#subset dataframe to keep only variable genes
tpm_var_genes = tpm.loc[var_df['sig']]
print(tpm_var_genes.shape)
tpm_var_genes.head()
# Out:
# (4067, 7216)
#                B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  \
# 4732440D04Rik                                           0.0
# Mcmdc2                                                  0.0
# Cspp1                                                   0.0
# Prdm14                                                  0.0
# Trpa1                                                   0.0
#
#                B1_AAACCGTGCCAAGT_Tuft  B1_AAACGCACAGCCTA_Goblet  \
# 4732440D04Rik                     0.0                       0.0
# Mcmdc2                            0.0                       0.0
# Cspp1                             0.0                       0.0
# Prdm14                            0.0                       0.0
# Trpa1                             0.0                       0.0
#
#                B1_AAACGCACCAGATC_Endocrine  B1_AAACGCACCGCCTT_Stem  \
# 4732440D04Rik                          0.0                     0.0
# Mcmdc2                                 0.0                     0.0
# Cspp1                                  0.0                     0.0
# Prdm14                                 0.0                     0.0
# Trpa1                                  0.0                     0.0
#
#                B1_AAACGCACCGTAGT_Stem  B1_AAACGGCTGATAGA_TA.Early  \
# 4732440D04Rik                     0.0                         0.0
# Mcmdc2                            0.0                         0.0
# Cspp1                             0.0                         0.0
# Prdm14                            0.0                         0.0
# Trpa1                             0.0                         0.0
#
#                B1_AAACTTGAAGAGTA_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                           0.0
# Mcmdc2                                                  0.0
# Cspp1                                                   0.0
# Prdm14                                                  0.0
# Trpa1                                                   0.0
#
#                B1_AAACTTGACCACAA_TA.G1  \
# 4732440D04Rik                      0.0
# Mcmdc2                             0.0
# Cspp1                              0.0
# Prdm14                             0.0
# Trpa1                              0.0
#
#                B1_AAAGACGATTGTCT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                           0.0
# Mcmdc2                                                  0.0
# Cspp1                                                   0.0
# Prdm14                                                  0.0
# Trpa1                                                   0.0
#
#                          ...              \
# 4732440D04Rik            ...
# Mcmdc2                   ...
# Cspp1                    ...
# Prdm14                   ...
# Trpa1                    ...
#
#                B10_TTCAGTTGCCTCGT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                            0.0
# Mcmdc2                                                   0.0
# Cspp1                                                    0.0
# Prdm14                                                   0.0
# Trpa1                                                    0.0
#
#                B10_TTCATGACCATTCT_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                             0.0
# Mcmdc2                                                    0.0
# Cspp1                                                     0.0
# Prdm14                                                    0.0
# Trpa1                                                     0.0
#
#                B10_TTCATGTGCGAGTT_Goblet  B10_TTCCAAACTAGAGA_Goblet  \
# 4732440D04Rik                        0.0                        0.0
# Mcmdc2                               0.0                        0.0
# Cspp1                                0.0                        0.0
# Prdm14                               0.0                        0.0
# Trpa1                                0.0                        0.0
#
#                B10_TTCGGAGAGACGTT_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                             0.0
# Mcmdc2                                                    0.0
# Cspp1                                                     0.0
# Prdm14                                                    0.0
# Trpa1                                                     0.0
#
#                B10_TTCTACGAATGCCA_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                             0.0
# Mcmdc2                                                    0.0
# Cspp1                                                     0.0
# Prdm14                                                    0.0
# Trpa1                                                     0.0
#
#                B10_TTCTGATGGCATCA_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                             0.0
# Mcmdc2                                                    0.0
# Cspp1                                                     0.0
# Prdm14                                                    0.0
# Trpa1                                                     0.0
#
#                B10_TTGACACTACCAAC_TA.G2  \
# 4732440D04Rik                       0.0
# Mcmdc2                              0.0
# Cspp1                               0.0
# Prdm14                              0.0
# Trpa1                               0.0
#
#                B10_TTGAGGTGTACTCT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                            0.0
# Mcmdc2                                                   0.0
# Cspp1                                                    0.0
# Prdm14                                                   0.0
# Trpa1                                                    0.0
#
#                B10_TTGCTATGGGCATT_Paneth
# 4732440D04Rik                   0.000000
# Mcmdc2                          0.000000
# Cspp1                           1.153891
# Prdm14                          0.000000
# Trpa1                           0.000000
#
# [5 rows x 7216 columns]

# %%
tpm_var_genes.to_csv(save_dir+"tpm_all_vg_0.05.csv")
