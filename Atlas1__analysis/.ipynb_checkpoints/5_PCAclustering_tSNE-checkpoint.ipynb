# %%
import pandas as pd
import numpy as np
from  sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import phenograph
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data_dir = "/home/ucsd-train13/scratch/projects/Atlas_full/processed_files/"

# %%
zscore_variable_genes = pd.read_csv(data_dir+"tpm_all_vg_0.05_zscores.csv", index_col=0)
print(zscore_variable_genes.shape)
zscore_variable_genes.head()
# Out:
# (4067, 7216)
#                B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  \
# 4732440D04Rik                                     -0.114306
# Mcmdc2                                            -0.027894
# Cspp1                                             -0.221910
# Prdm14                                            -0.028827
# Trpa1                                             -0.043380
#
#                B1_AAACCGTGCCAAGT_Tuft  B1_AAACGCACAGCCTA_Goblet  \
# 4732440D04Rik               -0.114306                 -0.114306
# Mcmdc2                      -0.027894                 -0.027894
# Cspp1                       -0.221910                 -0.221910
# Prdm14                      -0.028827                 -0.028827
# Trpa1                       -0.043380                 -0.043380
#
#                B1_AAACGCACCAGATC_Endocrine  B1_AAACGCACCGCCTT_Stem  \
# 4732440D04Rik                    -0.114306               -0.114306
# Mcmdc2                           -0.027894               -0.027894
# Cspp1                            -0.221910               -0.221910
# Prdm14                           -0.028827               -0.028827
# Trpa1                            -0.043380               -0.043380
#
#                B1_AAACGCACCGTAGT_Stem  B1_AAACGGCTGATAGA_TA.Early  \
# 4732440D04Rik               -0.114306                   -0.114306
# Mcmdc2                      -0.027894                   -0.027894
# Cspp1                       -0.221910                   -0.221910
# Prdm14                      -0.028827                   -0.028827
# Trpa1                       -0.043380                   -0.043380
#
#                B1_AAACTTGAAGAGTA_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                     -0.114306
# Mcmdc2                                            -0.027894
# Cspp1                                             -0.221910
# Prdm14                                            -0.028827
# Trpa1                                             -0.043380
#
#                B1_AAACTTGACCACAA_TA.G1  \
# 4732440D04Rik                -0.114306
# Mcmdc2                       -0.027894
# Cspp1                        -0.221910
# Prdm14                       -0.028827
# Trpa1                        -0.043380
#
#                B1_AAAGACGATTGTCT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                     -0.114306
# Mcmdc2                                            -0.027894
# Cspp1                                             -0.221910
# Prdm14                                            -0.028827
# Trpa1                                             -0.043380
#
#                          ...              \
# 4732440D04Rik            ...
# Mcmdc2                   ...
# Cspp1                    ...
# Prdm14                   ...
# Trpa1                    ...
#
#                B10_TTCAGTTGCCTCGT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                      -0.114306
# Mcmdc2                                             -0.027894
# Cspp1                                              -0.221910
# Prdm14                                             -0.028827
# Trpa1                                              -0.043380
#
#                B10_TTCATGACCATTCT_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                       -0.114306
# Mcmdc2                                              -0.027894
# Cspp1                                               -0.221910
# Prdm14                                              -0.028827
# Trpa1                                               -0.043380
#
#                B10_TTCATGTGCGAGTT_Goblet  B10_TTCCAAACTAGAGA_Goblet  \
# 4732440D04Rik                  -0.114306                  -0.114306
# Mcmdc2                         -0.027894                  -0.027894
# Cspp1                          -0.221910                  -0.221910
# Prdm14                         -0.028827                  -0.028827
# Trpa1                          -0.043380                  -0.043380
#
#                B10_TTCGGAGAGACGTT_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                       -0.114306
# Mcmdc2                                              -0.027894
# Cspp1                                               -0.221910
# Prdm14                                              -0.028827
# Trpa1                                               -0.043380
#
#                B10_TTCTACGAATGCCA_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                       -0.114306
# Mcmdc2                                              -0.027894
# Cspp1                                               -0.221910
# Prdm14                                              -0.028827
# Trpa1                                               -0.043380
#
#                B10_TTCTGATGGCATCA_Enterocyte.Progenitor.Early  \
# 4732440D04Rik                                       -0.114306
# Mcmdc2                                              -0.027894
# Cspp1                                               -0.221910
# Prdm14                                              -0.028827
# Trpa1                                               -0.043380
#
#                B10_TTGACACTACCAAC_TA.G2  \
# 4732440D04Rik                 -0.114306
# Mcmdc2                        -0.027894
# Cspp1                         -0.221910
# Prdm14                        -0.028827
# Trpa1                         -0.043380
#
#                B10_TTGAGGTGTACTCT_Enterocyte.Mature.Proximal  \
# 4732440D04Rik                                      -0.114306
# Mcmdc2                                             -0.027894
# Cspp1                                              -0.221910
# Prdm14                                             -0.028827
# Trpa1                                              -0.043380
#
#                B10_TTGCTATGGGCATT_Paneth
# 4732440D04Rik                  -0.114306
# Mcmdc2                         -0.027894
# Cspp1                           0.655883
# Prdm14                         -0.028827
# Trpa1                          -0.043380
#
# [5 rows x 7216 columns]

# %%
#Initiate a PCA object to be calculated with 200 components. 
pca = PCA(n_components=300)

#Fit our data with this PCA and save the result. PCA requires the samples (cells) to be the rows of the dataframe and 
#the measurements (genes) to be the columns. So we are going to transpose our dataframe with .T
pca_result = pca.fit_transform(zscore_variable_genes.T)

# %%
#The explained variance ratio will tell you how much of the variation in the dataset was captured by each component. 
#Notice there are 200 values in this array, that is because we kept 200 components.
#PCs are in decreasing order

pca.explained_variance_ratio_
# Out:
# array([0.01806827, 0.01151089, 0.00901044, 0.00866255, 0.00566567,
#        0.00440534, 0.00416421, 0.00390273, 0.00345033, 0.0033248 ,
#        0.00319278, 0.00300472, 0.00279894, 0.00251489, 0.0024628 ,
#        0.0023803 , 0.00234923, 0.00226868, 0.00221704, 0.00221097,
#        0.00216154, 0.00207857, 0.00204516, 0.00203255, 0.00194606,
#        0.00191096, 0.00184908, 0.00177077, 0.00174306, 0.00172821,
#        0.00171045, 0.00169455, 0.00167727, 0.00163901, 0.00162502,
#        0.00161829, 0.00159684, 0.00157518, 0.00156347, 0.00155108,
#        0.00152261, 0.00151847, 0.00151119, 0.00149706, 0.00146732,
#        0.00145758, 0.001446  , 0.00143224, 0.00142803, 0.0014133 ,
#        0.00139181, 0.00138774, 0.00137991, 0.00136581, 0.00134968,
#        0.00134556, 0.00133409, 0.00132594, 0.00131852, 0.00131457,
#        0.00130574, 0.00129636, 0.00129286, 0.00127881, 0.00126742,
#        0.00126709, 0.00126107, 0.00125059, 0.00124086, 0.00123922,
#        0.0012282 , 0.00122331, 0.00121488, 0.00120918, 0.00120117,
#        0.00118851, 0.00118227, 0.0011764 , 0.0011666 , 0.00116281,
#        0.00116147, 0.00115445, 0.00114588, 0.00114419, 0.00113784,
#        0.00113703, 0.00112811, 0.00112561, 0.00112438, 0.00111856,
#        0.0011143 , 0.0011082 , 0.00110186, 0.00110039, 0.00109709,
#        0.0010902 , 0.00108802, 0.0010862 , 0.00107981, 0.00107601,
#        0.00107421, 0.00106857, 0.00106818, 0.0010625 , 0.00106133,
#        0.32747194, 0.32825362, 0.32903468, 0.32981443, 0.33059306,
#        0.3313702 , 0.33214585, 0.33291921, 0.33369138, 0.3344614 ,
#        0.33523041, 0.33599436, 0.33675728, 0.33751921, 0.33827972,
#        0.3390381 , 0.33979538, 0.34055209, 0.34130721, 0.34206009,
#        0.34281044, 0.34356031, 0.34430966, 0.3450571 , 0.34580369,
#        0.34654697, 0.34728655, 0.34802462, 0.34876185, 0.34949715,
#        0.35023102, 0.35096274, 0.35169272, 0.35241974, 0.3531459 ,
#        0.3538709 , 0.35459469, 0.3553148 , 0.3560341 , 0.35675261,
#        0.35747046, 0.35818625, 0.35890148, 0.35961407, 0.36032394,
#        0.36103166, 0.36173778, 0.36244304, 0.36314598, 0.36384789,
#        0.36454767, 0.3652466 , 0.36594348, 0.36663927, 0.36733099,
#        0.36802161, 0.3687112 , 0.36939953, 0.37008632, 0.37077178,
#        0.37145382, 0.37213414, 0.37281093, 0.37348628, 0.37415911,
#        0.37483011, 0.37549844, 0.37616637, 0.3768333 , 0.37749748])

# %%
#make kneeplot to see where cumulative PCs form a knee 
sns.set_style("whitegrid")
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0,0.5,'cumulative explained variance')

# %%
# select significant components: there are several methods for this. We are going with the number used in the paper
pca_df = pd.DataFrame(pca_result)
pca_df.index = zscore_variable_genes.columns
print(pca_df.shape)
pca_df.head()
# Out:
# (7216, 300)
#                                                    0         1          2    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811   9.800459
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433  14.090662
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729  10.087999
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451  11.981695
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496  15.332018
#
#                                                    3          4         5    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.971940   2.114936 -3.085432
# B1_AAACCGTGCCAAGT_Tuft                        5.553612  -1.949900  1.840465
# B1_AAACGCACAGCCTA_Goblet                     -0.468681  16.833816  0.854982
# B1_AAACGCACCAGATC_Endocrine                  -3.907568  -2.071577 -1.617608
# B1_AAACGCACCGCCTT_Stem                       -1.848481  -1.351471  0.771529
#
#                                                    6         7         8    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -5.103839 -0.131911  0.309992
# B1_AAACCGTGCCAAGT_Tuft                        1.624023 -0.738360  1.689811
# B1_AAACGCACAGCCTA_Goblet                      5.750793 -5.051350 -1.952413
# B1_AAACGCACCAGATC_Endocrine                  -0.787372 -0.930891  1.844955
# B1_AAACGCACCGCCTT_Stem                        1.546536 -2.059449 -1.252707
#
#                                                    9      ...          290  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -2.854054    ...     0.377772
# B1_AAACCGTGCCAAGT_Tuft                        1.917652    ...     3.539288
# B1_AAACGCACAGCCTA_Goblet                      1.234311    ...     0.267799
# B1_AAACGCACCAGATC_Endocrine                  -1.942297    ...     0.490631
# B1_AAACGCACCGCCTT_Stem                       -0.330145    ...     0.003952
#
#                                                    291       292       293  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.044360 -0.278665 -0.882506
# B1_AAACCGTGCCAAGT_Tuft                       -1.039598 -0.551586 -0.973339
# B1_AAACGCACAGCCTA_Goblet                     -0.536299  0.196395  0.771647
# B1_AAACGCACCAGATC_Endocrine                  -1.021822  0.806151  0.379088
# B1_AAACGCACCGCCTT_Stem                        0.336082  0.391525  0.195091
#
#                                                    294       295       296  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.669741 -0.110514 -0.927756
# B1_AAACCGTGCCAAGT_Tuft                       -1.105161  0.943034  1.379018
# B1_AAACGCACAGCCTA_Goblet                      0.180100  0.339854 -0.167780
# B1_AAACGCACCAGATC_Endocrine                  -0.220296 -0.621158  1.061246
# B1_AAACGCACCGCCTT_Stem                       -0.120145 -0.796409  0.597864
#
#                                                    297       298       299
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.117395  0.899534 -0.320721
# B1_AAACCGTGCCAAGT_Tuft                        0.162852  0.542500  1.358770
# B1_AAACGCACAGCCTA_Goblet                      0.241441  1.426130 -0.630839
# B1_AAACGCACCAGATC_Endocrine                   1.431877  0.606260 -0.293851
# B1_AAACGCACCGCCTT_Stem                        1.186272 -0.384971 -0.498375
#
# [5 rows x 300 columns]

# %%
subset_PCA = pca_df[[0, 1]]
subset_PCA.head()
# Out:
#                                                      0         1
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496

# %%
subset_PCA.rename(columns = {0:'x', 1:'y'}, inplace=True)
# Out:
# /home/ucsd-train13/anaconda2/envs/py3_cshl/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
subset_PCA.head()
# Out:
#                                                      x         y
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496

# %%
temp = subset_PCA.reset_index()
temp.head()
# Out:
#                                           index         x         y
# 0  B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811
# 1                        B1_AAACCGTGCCAAGT_Tuft -7.711044  2.864433
# 2                      B1_AAACGCACAGCCTA_Goblet -5.170977  4.687729
# 3                   B1_AAACGCACCAGATC_Endocrine -4.732976  8.980451
# 4                        B1_AAACGCACCGCCTT_Stem -7.555880 -1.749496

# %%
temp ['batch'] = temp ['index'].apply(lambda x: x.split("_")[0])
temp.head()
# Out:
#                                           index         x         y batch
# 0  B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811    B1
# 1                        B1_AAACCGTGCCAAGT_Tuft -7.711044  2.864433    B1
# 2                      B1_AAACGCACAGCCTA_Goblet -5.170977  4.687729    B1
# 3                   B1_AAACGCACCAGATC_Endocrine -4.732976  8.980451    B1
# 4                        B1_AAACGCACCGCCTT_Stem -7.555880 -1.749496    B1

# %%
subset_PCA = temp.set_index ('index', drop=True)
subset_PCA.head()
# Out:
#                                                      x         y batch
# index
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811    B1
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433    B1
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729    B1
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451    B1
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496    B1

# %%
sns.set_style('white')

g = sns.lmplot('x', 'y', subset_PCA, hue='batch', fit_reg=False, 
              scatter_kws={"s":25}, size=8)
#we got PCAs we can use for clustering, but they are not very good for visualization

# %%
pca_df.head()
# Out:
#                                                    0         1          2    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811   9.800459
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433  14.090662
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729  10.087999
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451  11.981695
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496  15.332018
#
#                                                    3          4         5    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.971940   2.114936 -3.085432
# B1_AAACCGTGCCAAGT_Tuft                        5.553612  -1.949900  1.840465
# B1_AAACGCACAGCCTA_Goblet                     -0.468681  16.833816  0.854982
# B1_AAACGCACCAGATC_Endocrine                  -3.907568  -2.071577 -1.617608
# B1_AAACGCACCGCCTT_Stem                       -1.848481  -1.351471  0.771529
#
#                                                    6         7         8    \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -5.103839 -0.131911  0.309992
# B1_AAACCGTGCCAAGT_Tuft                        1.624023 -0.738360  1.689811
# B1_AAACGCACAGCCTA_Goblet                      5.750793 -5.051350 -1.952413
# B1_AAACGCACCAGATC_Endocrine                  -0.787372 -0.930891  1.844955
# B1_AAACGCACCGCCTT_Stem                        1.546536 -2.059449 -1.252707
#
#                                                    9      ...          290  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -2.854054    ...     0.377772
# B1_AAACCGTGCCAAGT_Tuft                        1.917652    ...     3.539288
# B1_AAACGCACAGCCTA_Goblet                      1.234311    ...     0.267799
# B1_AAACGCACCAGATC_Endocrine                  -1.942297    ...     0.490631
# B1_AAACGCACCGCCTT_Stem                       -0.330145    ...     0.003952
#
#                                                    291       292       293  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.044360 -0.278665 -0.882506
# B1_AAACCGTGCCAAGT_Tuft                       -1.039598 -0.551586 -0.973339
# B1_AAACGCACAGCCTA_Goblet                     -0.536299  0.196395  0.771647
# B1_AAACGCACCAGATC_Endocrine                  -1.021822  0.806151  0.379088
# B1_AAACGCACCGCCTT_Stem                        0.336082  0.391525  0.195091
#
#                                                    294       295       296  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.669741 -0.110514 -0.927756
# B1_AAACCGTGCCAAGT_Tuft                       -1.105161  0.943034  1.379018
# B1_AAACGCACAGCCTA_Goblet                      0.180100  0.339854 -0.167780
# B1_AAACGCACCAGATC_Endocrine                  -0.220296 -0.621158  1.061246
# B1_AAACGCACCGCCTT_Stem                       -0.120145 -0.796409  0.597864
#
#                                                    297       298       299
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.117395  0.899534 -0.320721
# B1_AAACCGTGCCAAGT_Tuft                        0.162852  0.542500  1.358770
# B1_AAACGCACAGCCTA_Goblet                      0.241441  1.426130 -0.630839
# B1_AAACGCACCAGATC_Endocrine                   1.431877  0.606260 -0.293851
# B1_AAACGCACCGCCTT_Stem                        1.186272 -0.384971 -0.498375
#
# [5 rows x 300 columns]

# %%
pca_df[pca_df.columns[:13]].head()
# Out:
#                                                     0         1          2   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811   9.800459
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433  14.090662
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729  10.087999
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451  11.981695
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496  15.332018
#
#                                                     3          4         5   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.971940   2.114936 -3.085432
# B1_AAACCGTGCCAAGT_Tuft                        5.553612  -1.949900  1.840465
# B1_AAACGCACAGCCTA_Goblet                     -0.468681  16.833816  0.854982
# B1_AAACGCACCAGATC_Endocrine                  -3.907568  -2.071577 -1.617608
# B1_AAACGCACCGCCTT_Stem                       -1.848481  -1.351471  0.771529
#
#                                                     6         7         8   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -5.103839 -0.131911  0.309992
# B1_AAACCGTGCCAAGT_Tuft                        1.624023 -0.738360  1.689811
# B1_AAACGCACAGCCTA_Goblet                      5.750793 -5.051350 -1.952413
# B1_AAACGCACCAGATC_Endocrine                  -0.787372 -0.930891  1.844955
# B1_AAACGCACCGCCTT_Stem                        1.546536 -2.059449 -1.252707
#
#                                                     9         10        11  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -2.854054  1.314439  4.096397
# B1_AAACCGTGCCAAGT_Tuft                        1.917652 -0.777976 -1.492934
# B1_AAACGCACAGCCTA_Goblet                      1.234311  1.323126 -2.792949
# B1_AAACGCACCAGATC_Endocrine                  -1.942297  1.986482  1.162909
# B1_AAACGCACCGCCTT_Stem                       -0.330145 -0.121517  1.549384
#
#                                                     12
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.341681
# B1_AAACCGTGCCAAGT_Tuft                       -0.842079
# B1_AAACGCACAGCCTA_Goblet                      0.238206
# B1_AAACGCACCAGATC_Endocrine                  -1.566189
# B1_AAACGCACCGCCTT_Stem                        0.439851

# %%
num_PCA_components_to_keep = 15

cols = list(range(num_PCA_components_to_keep))
subset = pca_df[cols]
print(subset.shape)
subset.head()
#to make subsetted dataframe that only contains the first 15 columns
# Out:
# (7216, 15)
#                                                     0         1          2   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.132621 -1.465811   9.800459
# B1_AAACCGTGCCAAGT_Tuft                       -7.711044  2.864433  14.090662
# B1_AAACGCACAGCCTA_Goblet                     -5.170977  4.687729  10.087999
# B1_AAACGCACCAGATC_Endocrine                  -4.732976  8.980451  11.981695
# B1_AAACGCACCGCCTT_Stem                       -7.555880 -1.749496  15.332018
#
#                                                     3          4         5   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -0.971940   2.114936 -3.085432
# B1_AAACCGTGCCAAGT_Tuft                        5.553612  -1.949900  1.840465
# B1_AAACGCACAGCCTA_Goblet                     -0.468681  16.833816  0.854982
# B1_AAACGCACCAGATC_Endocrine                  -3.907568  -2.071577 -1.617608
# B1_AAACGCACCGCCTT_Stem                       -1.848481  -1.351471  0.771529
#
#                                                     6         7         8   \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -5.103839 -0.131911  0.309992
# B1_AAACCGTGCCAAGT_Tuft                        1.624023 -0.738360  1.689811
# B1_AAACGCACAGCCTA_Goblet                      5.750793 -5.051350 -1.952413
# B1_AAACGCACCAGATC_Endocrine                  -0.787372 -0.930891  1.844955
# B1_AAACGCACCGCCTT_Stem                        1.546536 -2.059449 -1.252707
#
#                                                     9         10        11  \
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal -2.854054  1.314439  4.096397
# B1_AAACCGTGCCAAGT_Tuft                        1.917652 -0.777976 -1.492934
# B1_AAACGCACAGCCTA_Goblet                      1.234311  1.323126 -2.792949
# B1_AAACGCACCAGATC_Endocrine                  -1.942297  1.986482  1.162909
# B1_AAACGCACCGCCTT_Stem                       -0.330145 -0.121517  1.549384
#
#                                                     12        13        14
# B1_AAACATTGTTTGGG_Enterocyte.Immature.Distal  0.341681 -0.358957 -0.295122
# B1_AAACCGTGCCAAGT_Tuft                       -0.842079 -0.026157 -0.856964
# B1_AAACGCACAGCCTA_Goblet                      0.238206  0.415767 -0.422358
# B1_AAACGCACCAGATC_Endocrine                  -1.566189  0.318981 -1.153394
# B1_AAACGCACCGCCTT_Stem                        0.439851 -0.040174  0.206177

# %%
communities_300, sparse_matrix300, Q300 = phenograph.cluster(subset, k=300)
# Out:
# Finding 300 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.7046058177947998 seconds
# Jaccard graph constructed in 43.77119755744934 seconds
# Wrote graph to binary file in 4.732750177383423 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.773935
# Louvain completed 21 runs in 13.776096820831299 seconds
# PhenoGraph complete in 64.26612496376038 seconds

# %%
communities_500, sparse_matrix500, Q500 = phenograph.cluster(subset, k=500)
# Out:
# Finding 500 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.9716198444366455 seconds
# Jaccard graph constructed in 128.52346968650818 seconds
# Wrote graph to binary file in 8.030645370483398 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.739955
# Louvain completed 21 runs in 21.535290002822876 seconds
# PhenoGraph complete in 160.94326496124268 seconds

# %%
communities_100, sparse_matrix100, Q100 = phenograph.cluster(subset, k=100)
# Out:
# Finding 100 nearest neighbors using minkowski metric and 'auto' algorithm
# Neighbors computed in 1.1177470684051514 seconds
# Jaccard graph constructed in 6.9572532176971436 seconds
# Wrote graph to binary file in 1.8082072734832764 seconds
# Running Louvain modularity optimization
# After 1 runs, maximum modularity is Q = 0.823589
# After 2 runs, maximum modularity is Q = 0.825564
# After 6 runs, maximum modularity is Q = 0.826584
# After 12 runs, maximum modularity is Q = 0.828729
# Louvain completed 32 runs in 9.131176948547363 seconds
# PhenoGraph complete in 19.105165481567383 seconds
